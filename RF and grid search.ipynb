# %%
# importing required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.cluster import KMeans
from tqdm import tqdm
import time

train = pd.read_csv("CSV_train.csv",low_memory=False,delimiter=';')
test=pd.read_csv("CSV_test.csv",low_memory=False,delimiter=',')
hidden=pd.read_csv("CSV_hidden_test.csv",low_memory=False,delimiter=',')

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 136786 entries, 0 to 136785
# Data columns (total 28 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   WELL                              136786 non-null  object
#  1   DEPTH_MD                          136786 non-null  float64
#  2   X_LOC                             136727 non-null  float64
#  3   Y_LOC                             136727 non-null  float64
#  4   Z_LOC                             136727 non-null  float64
#  5   GROUP                             136786 non-null  object
#  6   FORMATION                         129712 non-null  object
#  7   CALI                              131141 non-null  float64
#  8   RSHA                              39097 non-null   float64
#  9   RMED                              136199 non-null  float64
#  10  RDEP                              136727 non-null  float64
#  11  RHOB                              119826 non-null  float64
#  12  GR                                136786 non-null  float64
#  13  SGR                               0 non-null       float64
#  14  NPHI                              104043 non-null  float64
#  15  PEF                               113503 non-null  float64
#  16  DTC                               135963 non-null  float64
#  17  SP                                66627 non-null   float64
#  18  BS                                66964 non-null   float64
#  19  ROP                               68316 non-null   float64
#  20  DTS                               43220 non-null   float64
#  21  DCAL                              13515 non-null   float64
#  22  DRHO                              111556 non-null  float64
#  23  MUDWEIGHT                         20269 non-null   float64
#  24  RMIC                              11316 non-null   float64
#  25  ROPA                              55790 non-null   float64
#  26  RXO                               29848 non-null   float64
#  27  FORCE_2020_LITHOFACIES_LITHOLOGY  136786 non-null  int64
# dtypes: float64(24), int64(1), object(3)
# memory usage: 29.2+ MB

# %%
# storing length of datasets 
train_len = train.shape[0] 
test_len = test.shape[0]
All_data = pd.concat((train,test,hidden)).reset_index(drop=True) 

lithology_keys = {30000: 'Sandstone',
                 65030: 'Sandstone/Shale',
                 65000: 'Shale',
                 80000: 'Marl',
                 74000: 'Dolomite',
                 70000: 'Limestone',
                 70032: 'Chalk',
                 88000: 'Halite',
                 86000: 'Anhydrite',
                 99000: 'Tuff',
                 90000: 'Coal',
                 93000: 'Basement'}
All_data['Lithology'] = All_data['FORCE_2020_LITHOFACIES_LITHOLOGY'].map(lithology_keys)
All_data
# Out:
#             WELL   DEPTH_MD         X_LOC      Y_LOC        Z_LOC  \
# 0        15/9-13   494.5280  437641.96875  6470972.5  -469.501831
# 1        15/9-13   494.6800  437641.96875  6470972.5  -469.653809
# 2        15/9-13   494.8320  437641.96875  6470972.5  -469.805786
# 3        15/9-13   494.9840  437641.96875  6470972.5  -469.957794
# 4        15/9-13   495.1360  437641.96875  6470972.5  -470.109772
# ...          ...        ...           ...        ...          ...
# 1429689   35/9-7  2973.2988  536096.06250  6793022.0 -2943.444580
# 1429690   35/9-7  2973.4508  536096.06250  6793022.0 -2943.595947
# 1429691   35/9-7  2973.6028  536096.06250  6793022.0 -2943.747559
# 1429692   35/9-7  2973.7548  536096.06250  6793022.0 -2943.899170
# 1429693   35/9-7  2973.9068  536096.06250  6793022.0 -2944.050537
#
#                 GROUP  FORMATION       CALI  RSHA      RMED  ...         DTS  \
# 0        NORDLAND GP.        NaN  19.480835   NaN  1.611410  ...         NaN
# 1        NORDLAND GP.        NaN  19.468800   NaN  1.618070  ...         NaN
# 2        NORDLAND GP.        NaN  19.468800   NaN  1.626459  ...         NaN
# 3        NORDLAND GP.        NaN  19.459282   NaN  1.621594  ...         NaN
# 4        NORDLAND GP.        NaN  19.453100   NaN  1.602679  ...         NaN
# ...               ...        ...        ...   ...       ...  ...         ...
# 1429689      BAAT GP.  Etive Fm.   8.276272   NaN  2.820439  ...  136.911575
# 1429690      BAAT GP.  Etive Fm.   8.267273   NaN  3.020778  ...  137.583923
# 1429691      BAAT GP.  Etive Fm.   8.250099   NaN  2.795711  ...  138.310898
# 1429692      BAAT GP.  Etive Fm.        NaN   NaN  2.658694  ...  137.592819
# 1429693      BAAT GP.  Etive Fm.        NaN   NaN  2.802693  ...  136.129761
#
#          DCAL      DRHO  MUDWEIGHT      RMIC       ROPA  RXO  \
# 0         NaN -0.574928        NaN       NaN        NaN  NaN
# 1         NaN -0.570188        NaN       NaN        NaN  NaN
# 2         NaN -0.574245        NaN       NaN        NaN  NaN
# 3         NaN -0.586315        NaN       NaN        NaN  NaN
# 4         NaN -0.597914        NaN       NaN        NaN  NaN
# ...       ...       ...        ...       ...        ...  ...
# 1429689   NaN  0.502458        NaN  2.311106  24.306124  NaN
# 1429690   NaN  0.374753        NaN  1.853418  22.201078  NaN
# 1429691   NaN  0.211487        NaN  1.325961  20.096741  NaN
# 1429692   NaN  0.147950        NaN  1.260347  17.992323  NaN
# 1429693   NaN  0.174232        NaN  1.266063  15.889325  NaN
#
#          FORCE_2020_LITHOFACIES_LITHOLOGY  FORCE_2020_LITHOFACIES_CONFIDENCE  \
# 0                                   65000                                1.0
# 1                                   65000                                1.0
# 2                                   65000                                1.0
# 3                                   65000                                1.0
# 4                                   65000                                1.0
# ...                                   ...                                ...
# 1429689                             65000                                2.0
# 1429690                             65000                                2.0
# 1429691                             65000                                2.0
# 1429692                             65000                                2.0
# 1429693                             65000                                2.0
#
#          Lithology
# 0            Shale
# 1            Shale
# 2            Shale
# 3            Shale
# 4            Shale
# ...            ...
# 1429689      Shale
# 1429690      Shale
# 1429691      Shale
# 1429692      Shale
# 1429693      Shale
#
# [1429694 rows x 30 columns]

# %%
#dropping columns with high missing values
drop_cols = ['SGR', 'ROPA', 'RXO', 'MUDWEIGHT','DCAL','RMIC','FORCE_2020_LITHOFACIES_CONFIDENCE']
All_data_drop = All_data.drop(drop_cols, axis=1)

# %%
All_data_drop
# Out:
#             WELL   DEPTH_MD         X_LOC      Y_LOC        Z_LOC  \
# 0        15/9-13   494.5280  437641.96875  6470972.5  -469.501831
# 1        15/9-13   494.6800  437641.96875  6470972.5  -469.653809
# 2        15/9-13   494.8320  437641.96875  6470972.5  -469.805786
# 3        15/9-13   494.9840  437641.96875  6470972.5  -469.957794
# 4        15/9-13   495.1360  437641.96875  6470972.5  -470.109772
# ...          ...        ...           ...        ...          ...
# 1429689   35/9-7  2973.2988  536096.06250  6793022.0 -2943.444580
# 1429690   35/9-7  2973.4508  536096.06250  6793022.0 -2943.595947
# 1429691   35/9-7  2973.6028  536096.06250  6793022.0 -2943.747559
# 1429692   35/9-7  2973.7548  536096.06250  6793022.0 -2943.899170
# 1429693   35/9-7  2973.9068  536096.06250  6793022.0 -2944.050537
#
#                 GROUP  FORMATION       CALI  RSHA      RMED  ...  NPHI  \
# 0        NORDLAND GP.        NaN  19.480835   NaN  1.611410  ...   NaN
# 1        NORDLAND GP.        NaN  19.468800   NaN  1.618070  ...   NaN
# 2        NORDLAND GP.        NaN  19.468800   NaN  1.626459  ...   NaN
# 3        NORDLAND GP.        NaN  19.459282   NaN  1.621594  ...   NaN
# 4        NORDLAND GP.        NaN  19.453100   NaN  1.602679  ...   NaN
# ...               ...        ...        ...   ...       ...  ...   ...
# 1429689      BAAT GP.  Etive Fm.   8.276272   NaN  2.820439  ...   NaN
# 1429690      BAAT GP.  Etive Fm.   8.267273   NaN  3.020778  ...   NaN
# 1429691      BAAT GP.  Etive Fm.   8.250099   NaN  2.795711  ...   NaN
# 1429692      BAAT GP.  Etive Fm.        NaN   NaN  2.658694  ...   NaN
# 1429693      BAAT GP.  Etive Fm.        NaN   NaN  2.802693  ...   NaN
#
#                PEF         DTC         SP   BS        ROP         DTS  \
# 0        20.915468  161.131180  24.612379  NaN  34.636410         NaN
# 1        19.383013  160.603470  23.895531  NaN  34.636410         NaN
# 2        22.591518  160.173615  23.916357  NaN  34.779556         NaN
# 3        32.191910  160.149429  23.793688  NaN  39.965164         NaN
# 4        38.495632  160.128342  24.104078  NaN  57.483765         NaN
# ...            ...         ...        ...  ...        ...         ...
# 1429689        NaN   75.260658        NaN  8.5  15.195305  136.911575
# 1429690        NaN   74.868301        NaN  8.5  15.770223  137.583923
# 1429691        NaN   74.848122        NaN  8.5  16.418465  138.310898
# 1429692        NaN   74.964027        NaN  8.5  17.037945  137.592819
# 1429693        NaN   75.111404        NaN  8.5  17.618532  136.129761
#
#              DRHO  FORCE_2020_LITHOFACIES_LITHOLOGY  Lithology
# 0       -0.574928                             65000      Shale
# 1       -0.570188                             65000      Shale
# 2       -0.574245                             65000      Shale
# 3       -0.586315                             65000      Shale
# 4       -0.597914                             65000      Shale
# ...           ...                               ...        ...
# 1429689  0.502458                             65000      Shale
# 1429690  0.374753                             65000      Shale
# 1429691  0.211487                             65000      Shale
# 1429692  0.147950                             65000      Shale
# 1429693  0.174232                             65000      Shale
#
# [1429694 rows x 23 columns]

# %%
All_data_drop.columns
# Out:
# Index(['WELL', 'DEPTH_MD', 'X_LOC', 'Y_LOC', 'Z_LOC', 'GROUP', 'FORMATION',
#        'CALI', 'RSHA', 'RMED', 'RDEP', 'RHOB', 'GR', 'NPHI', 'PEF', 'DTC',
#        'SP', 'BS', 'ROP', 'DTS', 'DRHO', 'FORCE_2020_LITHOFACIES_LITHOLOGY',
#        'Lithology'],
#       dtype='object')

# %%
#Inputing missing values by introducing median 
from sklearn.impute import SimpleImputer

numeric_header=['DEPTH_MD', 'X_LOC', 'Y_LOC', 'Z_LOC',
       'CALI', 'RSHA', 'RMED', 'RDEP', 'RHOB', 'GR', 'NPHI', 'PEF', 'DTC',
       'SP', 'BS', 'ROP', 'DTS', 'DRHO', 'FORCE_2020_LITHOFACIES_LITHOLOGY'
       ]
categorical_header=['WELL','GROUP', 'FORMATION','Lithology']
numeric=All_data_drop.select_dtypes(include=[np.number])
categorical= All_data_drop.select_dtypes(exclude=[np.number])
miss = SimpleImputer(missing_values=np.nan, strategy='median')
miss.fit(numeric)
numeric_imp = miss.fit_transform(numeric)
numeric_imp=pd.DataFrame(numeric_imp, columns=numeric_header)
miss2 = SimpleImputer(missing_values=np.nan, strategy='most_frequent')
miss2.fit(categorical)
categorical_imp = miss2.fit_transform(categorical)
categorical_imp=pd.DataFrame(categorical_imp, columns=categorical_header)
frames = [numeric_imp,categorical_imp]
  
result = pd.concat(frames,axis=1, join='inner')
result
# Out:
#           DEPTH_MD         X_LOC      Y_LOC        Z_LOC       CALI      RSHA  \
# 0         494.5280  437641.96875  6470972.5  -469.501831  19.480835  1.398049
# 1         494.6800  437641.96875  6470972.5  -469.653809  19.468800  1.398049
# 2         494.8320  437641.96875  6470972.5  -469.805786  19.468800  1.398049
# 3         494.9840  437641.96875  6470972.5  -469.957794  19.459282  1.398049
# 4         495.1360  437641.96875  6470972.5  -470.109772  19.453100  1.398049
# ...            ...           ...        ...          ...        ...       ...
# 1429689  2973.2988  536096.06250  6793022.0 -2943.444580   8.276272  1.398049
# 1429690  2973.4508  536096.06250  6793022.0 -2943.595947   8.267273  1.398049
# 1429691  2973.6028  536096.06250  6793022.0 -2943.747559   8.250099  1.398049
# 1429692  2973.7548  536096.06250  6793022.0 -2943.899170  12.515673  1.398049
# 1429693  2973.9068  536096.06250  6793022.0 -2944.050537  12.515673  1.398049
#
#              RMED      RDEP      RHOB          GR  ...         SP         BS  \
# 0        1.611410  1.798681  1.884186   80.200851  ...  24.612379  12.250001
# 1        1.618070  1.795641  1.889794   79.262886  ...  23.895531  12.250001
# 2        1.626459  1.800733  1.896523   74.821999  ...  23.916357  12.250001
# 3        1.621594  1.801517  1.891913   72.878922  ...  23.793688  12.250001
# 4        1.602679  1.795299  1.880034   71.729141  ...  24.104078  12.250001
# ...           ...       ...       ...         ...  ...        ...        ...
# 1429689  2.820439  3.158570  2.331407   90.720284  ...  54.270451   8.500000
# 1429690  3.020778  3.332977  2.331407   87.062027  ...  54.270451   8.500000
# 1429691  2.795711  3.044179  2.331407   86.115921  ...  54.270451   8.500000
# 1429692  2.658694  2.847681  2.331407   89.497131  ...  54.270451   8.500000
# 1429693  2.802693  2.972499  2.331407  100.418251  ...  54.270451   8.500000
#
#                ROP         DTS      DRHO  FORCE_2020_LITHOFACIES_LITHOLOGY  \
# 0        34.636410  189.362198 -0.574928                           65000.0
# 1        34.636410  189.362198 -0.570188                           65000.0
# 2        34.779556  189.362198 -0.574245                           65000.0
# 3        39.965164  189.362198 -0.586315                           65000.0
# 4        57.483765  189.362198 -0.597914                           65000.0
# ...            ...         ...       ...                               ...
# 1429689  15.195305  136.911575  0.502458                           65000.0
# 1429690  15.770223  137.583923  0.374753                           65000.0
# 1429691  16.418465  138.310898  0.211487                           65000.0
# 1429692  17.037945  137.592819  0.147950                           65000.0
# 1429693  17.618532  136.129761  0.174232                           65000.0
#
#             WELL         GROUP   FORMATION Lithology
# 0        15/9-13  NORDLAND GP.  Utsira Fm.     Shale
# 1        15/9-13  NORDLAND GP.  Utsira Fm.     Shale
# 2        15/9-13  NORDLAND GP.  Utsira Fm.     Shale
# 3        15/9-13  NORDLAND GP.  Utsira Fm.     Shale
# 4        15/9-13  NORDLAND GP.  Utsira Fm.     Shale
# ...          ...           ...         ...       ...
# 1429689   35/9-7      BAAT GP.   Etive Fm.     Shale
# 1429690   35/9-7      BAAT GP.   Etive Fm.     Shale
# 1429691   35/9-7      BAAT GP.   Etive Fm.     Shale
# 1429692   35/9-7      BAAT GP.   Etive Fm.     Shale
# 1429693   35/9-7      BAAT GP.   Etive Fm.     Shale
#
# [1429694 rows x 23 columns]

# %%
# encoding categorical variables
result['GROUP_encoded'] = result['GROUP'].astype('category')
result['GROUP_encoded'] = result['GROUP_encoded'].cat.codes

result['FORMATION_encoded'] = result['FORMATION'].astype('category')
result['FORMATION_encoded'] = result['FORMATION_encoded'].cat.codes

result['WELL_encoded'] = result['WELL'].astype('category')
result['WELL_encoded'] = result['WELL_encoded'].cat.codes

result['Lithology_encoded'] = result['FORCE_2020_LITHOFACIES_LITHOLOGY'].astype('category')
result['Lithology_encoded'] = result['Lithology_encoded'].cat.codes

# %%
train_imp = result[:train_len].copy()
test_imp = result[train_len:(train_len+test_len)].copy()
hidden_imp = result[(train_len+test_len):].copy()

# %%
print(train_imp.shape)
print(test_imp.shape)
print(hidden_imp.shape)
# Out:
# (1170511, 27)
# (136786, 27)
# (122397, 27)

# %%
from sklearn.preprocessing import StandardScaler, Normalizer, MinMaxScaler
x_header=['DEPTH_MD', 'X_LOC', 'Y_LOC', 'Z_LOC', 'CALI', 'RSHA', 'RMED', 'RDEP',
       'RHOB', 'GR', 'NPHI', 'PEF', 'DTC', 'SP', 'BS', 'ROP', 'DTS', 'DRHO',
       'GROUP_encoded', 'FORMATION_encoded', 'WELL_encoded']
y_header=['Lithology_encoded']
x_train = train_imp[x_header]
y_train = train_imp[y_header]
x_test = test_imp[x_header]
y_test = test_imp[y_header]
x_hidden = hidden_imp[x_header]
y_hidden = hidden_imp[y_header]

##Min-Max scaler 
scaler = MinMaxScaler()
x_train_scaled = x_train.copy()
x_test_scaled = x_test.copy()
x_hidden_scaled = x_hidden.copy()

x_train_scaled.iloc[:,:18] = scaler.fit_transform(x_train_scaled.iloc[:,:18])
x_test_scaled.iloc[:,:18] = scaler.transform(x_test_scaled.iloc[:,:18])
x_hidden_scaled.iloc[:,:18] = scaler.transform(x_hidden_scaled.iloc[:,:18])

# %%
from sklearn.model_selection import cross_val_score

new_train = pd.concat((x_train_scaled, pd.DataFrame(y_train, columns=["Lithology_encoded"])), axis=1)

#Randomly sampling data
sampled_train = new_train.sample(n=50000, random_state=0)


#Spliting training data
x_train_sam = sampled_train.drop(["Lithology_encoded"], axis=1)
y_train_sam = sampled_train["Lithology_encoded"]

# %%
#X_train, X_test, Y_train, Y_test = train_test_split( X, y, test_size=0.10, random_state=42,stratify=y)

# %%
# A = np.load('penalty_matrix.npy')
# def score(y_true, y_pred):
#     S = 0.0
#     y_true = y_true.astype(int)
#     y_pred = y_pred.astype(int)
#     for i in range(0, y_true.shape[0]):
#         S -= A[y_true[i], y_pred[i]]
#     return S/y_true.shape[0]

# %%
#Supervised Algorithms
from sklearn import model_selection
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import mean_squared_error, accuracy_score, recall_score, precision_score, f1_score
from sklearn.neighbors import KNeighborsRegressor
from pprint import pprint
from sklearn.model_selection import StratifiedKFold
from sklearn.naive_bayes import GaussianNB
import xgboost
from xgboost import XGBClassifier
from sklearn.neighbors import KNeighborsClassifier
#Comparing base models accuracies by using k-fold cross validation - 10 folds

from sklearn.model_selection import cross_val_score

model_rf = RandomForestClassifier()
                                    


model_rf.fit(x_train_sam, y_train_sam.values.ravel())
             
# train_pred_rf = model_rf.predict(x_train)
# open_pred_rf = model_rf.predict(x_test)
# hidden_pred_rf = model_rf.predict(x_hidden)
#Printing Reports
# Out:
# C:\Users\Ayori\anaconda3\lib\site-packages\xgboost\compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# RandomForestClassifier()

# %%
# from sklearn.metrics import classification_report, accuracy_score
# print('-----------------------TRAIN SET REPORT---------------------')
# print("Open set RMSE:", np.sqrt(mean_squared_error(y_train, train_pred_rf)))
# print('Open set penalty matrix score:', score(y_train.values, train_pred_rf))
# print('Open set report:', classification_report(y_train, train_pred_rf))
# print('-----------------------OPEN SET REPORT---------------------')
# print("Open set RMSE:", np.sqrt(mean_squared_error(y_test, open_pred_rf)))
# print('Open set penalty matrix score:', score(y_test.values, open_pred_rf))
# print('Open set report:', classification_report(y_test, open_pred_rf))
# print('-----------------------HIDDEN SET REPORT---------------------')
# print("Hidden set RMSE:", np.sqrt(mean_squared_error(y_hidden, hidden_pred_rf)))
# print('Hidden set penalty matrix score:', score(y_hidden.values, hidden_pred_rf))
# print('Hidden set report:', classification_report(y_hidden, hidden_pred_rf))

# %%
def grid_search(model):
    param_grid = {'n_estimators': [100, 150,200],
           'max_depth': [10,15,20],'max_features': ['auto', 'sqrt'],'min_samples_leaf' : [1, 2, 4],
           'criterion': ['gini', 'entropy']}
    model_cv = model_selection.GridSearchCV(estimator=model, param_grid=param_grid,
                                          scoring='f1_weighted', verbose=10, n_jobs=1, cv=10)
    model_cv.fit(x_train_sam, y_train_sam)

    print("Best score is: {}".format(model_cv.best_score_))
    print("Tuned Model Parameter: {}".format(model_cv.best_params_))

# %%
grid_search(model_rf)
# Out:
# Fitting 10 folds for each of 108 candidates, totalling 1080 fits
# [CV 1/10; 1/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, n_estimators=100
# C:\Users\Ayori\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:666: UserWarning: The least populated class in y has only 9 members, which is less than n_splits=10.
#   warnings.warn(("The least populated class in y has only %d"
# [CV 1/10; 1/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, n_estimators=100;, score=0.811 total time=  10.0s
# [CV 2/10; 1/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, n_estimators=100
# [CV 2/10; 1/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, n_estimators=100;, score=0.815 total time=  10.9s
# [CV 3/10; 1/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, n_estimators=100
# [CV 3/10; 1/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, n_estimators=100;, score=0.817 total time=  10.6s
# [CV 4/10; 1/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, n_estimators=100
# [CV 4/10; 1/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, n_estimators=100;, score=0.819 total time=  11.4s
# [CV 5/10; 1/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, n_estimators=100
# [CV 5/10; 1/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, n_estimators=100;, score=0.811 total time=  10.4s
# [CV 6/10; 1/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, n_estimators=100
# [CV 6/10; 1/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, n_estimators=100;, score=0.816 total time=  10.7s
# [CV 7/10; 1/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, n_estimators=100
# [CV 7/10; 1/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, n_estimators=100;, score=0.814 total time=  10.6s
# [CV 8/10; 1/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, n_estimators=100
# [CV 8/10; 1/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, n_estimators=100;, score=0.813 total time=  10.7s
# [CV 9/10; 1/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, n_estimators=100
# [CV 9/10; 1/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, n_estimators=100;, score=0.806 total time=  10.5s
# [CV 10/10; 1/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, n_estimators=100
# [CV 10/10; 1/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, n_estimators=100;, score=0.816 total time=  11.0s
# [CV 1/10; 2/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, n_estimators=150
# [CV 1/10; 2/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, n_estimators=150;, score=0.813 total time=  15.7s
# [CV 2/10; 2/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, n_estimators=150
# [CV 2/10; 2/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, n_estimators=150;, score=0.809 total time=  16.2s
# [CV 3/10; 2/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, n_estimators=150
# [CV 3/10; 2/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, n_estimators=150;, score=0.812 total time=  15.6s
# [CV 4/10; 2/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, n_estimators=150
# [CV 4/10; 2/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, n_estimators=150;, score=0.820 total time=  16.5s
# [CV 5/10; 2/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, n_estimators=150
# [CV 5/10; 2/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, n_estimators=150;, score=0.807 total time=  19.3s
# [CV 6/10; 2/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, n_estimators=150
# [CV 6/10; 2/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, n_estimators=150;, score=0.820 total time=  15.8s
# [CV 7/10; 2/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, n_estimators=150
# [CV 7/10; 2/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, n_estimators=150;, score=0.816 total time=  14.9s
# [CV 8/10; 2/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, n_estimators=150
# [CV 8/10; 2/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, n_estimators=150;, score=0.813 total time=  15.5s
# [CV 9/10; 2/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, n_estimators=150
# [CV 9/10; 2/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, n_estimators=150;, score=0.805 total time=  16.1s
# [CV 10/10; 2/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, n_estimators=150
# [CV 10/10; 2/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, n_estimators=150;, score=0.815 total time=  16.2s
# [CV 1/10; 3/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, n_estimators=200
# [CV 1/10; 3/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, n_estimators=200;, score=0.814 total time=  19.0s
# [CV 2/10; 3/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, n_estimators=200
# [CV 2/10; 3/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, n_estimators=200;, score=0.815 total time=  20.5s
# [CV 3/10; 3/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, n_estimators=200
# [CV 3/10; 3/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, n_estimators=200;, score=0.815 total time=  22.3s
# [CV 4/10; 3/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, n_estimators=200
# [CV 4/10; 3/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, n_estimators=200;, score=0.819 total time=  25.4s
# [CV 5/10; 3/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, n_estimators=200
# [CV 5/10; 3/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, n_estimators=200;, score=0.809 total time=  22.0s
# [CV 6/10; 3/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, n_estimators=200
# [CV 6/10; 3/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, n_estimators=200;, score=0.817 total time=  20.7s
# [CV 7/10; 3/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, n_estimators=200
# [CV 7/10; 3/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, n_estimators=200;, score=0.812 total time=  20.9s
# [CV 8/10; 3/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, n_estimators=200
# [CV 8/10; 3/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, n_estimators=200;, score=0.813 total time=  20.3s
# [CV 9/10; 3/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, n_estimators=200
# [CV 9/10; 3/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, n_estimators=200;, score=0.812 total time=  20.7s
# [CV 10/10; 3/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, n_estimators=200
# [CV 10/10; 3/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, n_estimators=200;, score=0.814 total time=  19.9s
# [CV 1/10; 4/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, n_estimators=100
# [CV 1/10; 4/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, n_estimators=100;, score=0.809 total time=   9.1s
# [CV 2/10; 4/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, n_estimators=100
# [CV 2/10; 4/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, n_estimators=100;, score=0.812 total time=   9.4s
# [CV 3/10; 4/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, n_estimators=100
# [CV 3/10; 4/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, n_estimators=100;, score=0.813 total time=  10.3s
# [CV 4/10; 4/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, n_estimators=100
# [CV 4/10; 4/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, n_estimators=100;, score=0.814 total time=   9.7s
# [CV 5/10; 4/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, n_estimators=100
# [CV 5/10; 4/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, n_estimators=100;, score=0.807 total time=   9.7s
# [CV 6/10; 4/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, n_estimators=100
# [CV 6/10; 4/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, n_estimators=100;, score=0.824 total time=  10.3s
# [CV 7/10; 4/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, n_estimators=100
# [CV 7/10; 4/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, n_estimators=100;, score=0.815 total time=   9.8s
# [CV 8/10; 4/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, n_estimators=100
# [CV 8/10; 4/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, n_estimators=100;, score=0.813 total time=  10.2s
# [CV 9/10; 4/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, n_estimators=100
# [CV 9/10; 4/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, n_estimators=100;, score=0.809 total time=   9.4s
# [CV 10/10; 4/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, n_estimators=100
# [CV 10/10; 4/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, n_estimators=100;, score=0.814 total time=   9.2s
# [CV 1/10; 5/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, n_estimators=150
# [CV 1/10; 5/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, n_estimators=150;, score=0.813 total time=  15.0s
# [CV 2/10; 5/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, n_estimators=150
# [CV 2/10; 5/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, n_estimators=150;, score=0.811 total time=  14.6s
# [CV 3/10; 5/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, n_estimators=150
# [CV 3/10; 5/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, n_estimators=150;, score=0.813 total time=  14.7s
# [CV 4/10; 5/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, n_estimators=150
# [CV 4/10; 5/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, n_estimators=150;, score=0.813 total time=  14.8s
# [CV 5/10; 5/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, n_estimators=150
# [CV 5/10; 5/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, n_estimators=150;, score=0.806 total time=  15.4s
# [CV 6/10; 5/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, n_estimators=150
# [CV 6/10; 5/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, n_estimators=150;, score=0.815 total time=  14.7s
# [CV 7/10; 5/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, n_estimators=150
# [CV 7/10; 5/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, n_estimators=150;, score=0.809 total time=  14.7s
# [CV 8/10; 5/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, n_estimators=150
# [CV 8/10; 5/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, n_estimators=150;, score=0.811 total time=  14.6s
# [CV 9/10; 5/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, n_estimators=150
# [CV 9/10; 5/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, n_estimators=150;, score=0.811 total time=  14.7s
# [CV 10/10; 5/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, n_estimators=150
# [CV 10/10; 5/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, n_estimators=150;, score=0.815 total time=  14.6s
# [CV 1/10; 6/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, n_estimators=200
# [CV 1/10; 6/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, n_estimators=200;, score=0.813 total time=  19.6s
# [CV 2/10; 6/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, n_estimators=200
# [CV 2/10; 6/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, n_estimators=200;, score=0.813 total time=  19.5s
# [CV 3/10; 6/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, n_estimators=200
# [CV 3/10; 6/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, n_estimators=200;, score=0.815 total time=  19.4s
# [CV 4/10; 6/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, n_estimators=200
# [CV 4/10; 6/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, n_estimators=200;, score=0.816 total time=  19.5s
# [CV 5/10; 6/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, n_estimators=200
# [CV 5/10; 6/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, n_estimators=200;, score=0.807 total time=  23.1s
# [CV 6/10; 6/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, n_estimators=200
# [CV 6/10; 6/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, n_estimators=200;, score=0.819 total time=  19.6s
# [CV 7/10; 6/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, n_estimators=200
# [CV 7/10; 6/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, n_estimators=200;, score=0.812 total time=  18.8s
# [CV 8/10; 6/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, n_estimators=200
# [CV 8/10; 6/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, n_estimators=200;, score=0.813 total time=  18.7s
# [CV 9/10; 6/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, n_estimators=200
# [CV 9/10; 6/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, n_estimators=200;, score=0.808 total time=  19.0s
# [CV 10/10; 6/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, n_estimators=200
# [CV 10/10; 6/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, n_estimators=200;, score=0.815 total time=  18.8s
# [CV 1/10; 7/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, n_estimators=100
# [CV 1/10; 7/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, n_estimators=100;, score=0.807 total time=   9.7s
# [CV 2/10; 7/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, n_estimators=100
# [CV 2/10; 7/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, n_estimators=100;, score=0.807 total time=   9.5s
# [CV 3/10; 7/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, n_estimators=100
# [CV 3/10; 7/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, n_estimators=100;, score=0.811 total time=   9.4s
# [CV 4/10; 7/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, n_estimators=100
# [CV 4/10; 7/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, n_estimators=100;, score=0.817 total time=   9.3s
# [CV 5/10; 7/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, n_estimators=100
# [CV 5/10; 7/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, n_estimators=100;, score=0.806 total time=   9.4s
# [CV 6/10; 7/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, n_estimators=100
# [CV 6/10; 7/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, n_estimators=100;, score=0.818 total time=   9.7s
# [CV 7/10; 7/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, n_estimators=100
# [CV 7/10; 7/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, n_estimators=100;, score=0.811 total time=   9.6s
# [CV 8/10; 7/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, n_estimators=100
# [CV 8/10; 7/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, n_estimators=100;, score=0.811 total time=   9.4s
# [CV 9/10; 7/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, n_estimators=100
# [CV 9/10; 7/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, n_estimators=100;, score=0.806 total time=   9.5s
# [CV 10/10; 7/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, n_estimators=100
# [CV 10/10; 7/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, n_estimators=100;, score=0.811 total time=   9.4s
# [CV 1/10; 8/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, n_estimators=150
# [CV 1/10; 8/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, n_estimators=150;, score=0.810 total time=  14.1s
# [CV 2/10; 8/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, n_estimators=150
# [CV 2/10; 8/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, n_estimators=150;, score=0.808 total time=  14.7s
# [CV 3/10; 8/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, n_estimators=150
# [CV 3/10; 8/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, n_estimators=150;, score=0.812 total time=  14.6s
# [CV 4/10; 8/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, n_estimators=150
# [CV 4/10; 8/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, n_estimators=150;, score=0.815 total time=  14.5s
# [CV 5/10; 8/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, n_estimators=150
# [CV 5/10; 8/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, n_estimators=150;, score=0.807 total time=  14.9s
# [CV 6/10; 8/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, n_estimators=150
# [CV 6/10; 8/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, n_estimators=150;, score=0.817 total time=  22.1s
# [CV 7/10; 8/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, n_estimators=150
# [CV 7/10; 8/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, n_estimators=150;, score=0.812 total time=  15.4s
# [CV 8/10; 8/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, n_estimators=150
# [CV 8/10; 8/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, n_estimators=150;, score=0.806 total time=  18.7s
# [CV 9/10; 8/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, n_estimators=150
# [CV 9/10; 8/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, n_estimators=150;, score=0.806 total time=  17.1s
# [CV 10/10; 8/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, n_estimators=150
# [CV 10/10; 8/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, n_estimators=150;, score=0.815 total time=  15.9s
# [CV 1/10; 9/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, n_estimators=200
# [CV 1/10; 9/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, n_estimators=200;, score=0.810 total time=  20.2s
# [CV 2/10; 9/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, n_estimators=200
# [CV 2/10; 9/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, n_estimators=200;, score=0.811 total time=  19.3s
# [CV 3/10; 9/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, n_estimators=200
# [CV 3/10; 9/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, n_estimators=200;, score=0.814 total time=  19.7s
# [CV 4/10; 9/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, n_estimators=200
# [CV 4/10; 9/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, n_estimators=200;, score=0.817 total time=  20.2s
# [CV 5/10; 9/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, n_estimators=200
# [CV 5/10; 9/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, n_estimators=200;, score=0.806 total time=  21.2s
# [CV 6/10; 9/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, n_estimators=200
# [CV 6/10; 9/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, n_estimators=200;, score=0.817 total time=  20.9s
# [CV 7/10; 9/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, n_estimators=200
# [CV 7/10; 9/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, n_estimators=200;, score=0.812 total time=  20.7s
# [CV 8/10; 9/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, n_estimators=200
# [CV 8/10; 9/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, n_estimators=200;, score=0.812 total time=  22.2s
# [CV 9/10; 9/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, n_estimators=200
# [CV 9/10; 9/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, n_estimators=200;, score=0.807 total time=  23.7s
# [CV 10/10; 9/108] START criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, n_estimators=200
# [CV 10/10; 9/108] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, n_estimators=200;, score=0.813 total time=  21.6s
# [CV 1/10; 10/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, n_estimators=100
# [CV 1/10; 10/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, n_estimators=100;, score=0.812 total time=  10.5s
# [CV 2/10; 10/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, n_estimators=100
# [CV 2/10; 10/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, n_estimators=100;, score=0.813 total time=  10.0s
# [CV 3/10; 10/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, n_estimators=100
# [CV 3/10; 10/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, n_estimators=100;, score=0.817 total time=  10.1s
# [CV 4/10; 10/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, n_estimators=100
# [CV 4/10; 10/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, n_estimators=100;, score=0.820 total time=  10.4s
# [CV 5/10; 10/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, n_estimators=100
# [CV 5/10; 10/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, n_estimators=100;, score=0.801 total time=  10.2s
# [CV 6/10; 10/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, n_estimators=100
# [CV 6/10; 10/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, n_estimators=100;, score=0.819 total time=  10.0s
# [CV 7/10; 10/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, n_estimators=100
# [CV 7/10; 10/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, n_estimators=100;, score=0.811 total time=  10.3s
# [CV 8/10; 10/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, n_estimators=100
# [CV 8/10; 10/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, n_estimators=100;, score=0.811 total time=   9.9s
# [CV 9/10; 10/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, n_estimators=100
# [CV 9/10; 10/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, n_estimators=100;, score=0.808 total time=  11.2s
# [CV 10/10; 10/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, n_estimators=100
# [CV 10/10; 10/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, n_estimators=100;, score=0.816 total time=  10.8s
# [CV 1/10; 11/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, n_estimators=150
# [CV 1/10; 11/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, n_estimators=150;, score=0.811 total time=  16.0s
# [CV 2/10; 11/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, n_estimators=150
# [CV 2/10; 11/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, n_estimators=150;, score=0.811 total time=  15.4s
# [CV 3/10; 11/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, n_estimators=150
# [CV 3/10; 11/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, n_estimators=150;, score=0.817 total time=  14.2s
# [CV 4/10; 11/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, n_estimators=150
# [CV 4/10; 11/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, n_estimators=150;, score=0.819 total time=  14.4s
# [CV 5/10; 11/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, n_estimators=150
# [CV 5/10; 11/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, n_estimators=150;, score=0.804 total time=  14.5s
# [CV 6/10; 11/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, n_estimators=150
# [CV 6/10; 11/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, n_estimators=150;, score=0.815 total time=  15.5s
# [CV 7/10; 11/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, n_estimators=150
# [CV 7/10; 11/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, n_estimators=150;, score=0.815 total time=  15.6s
# [CV 8/10; 11/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, n_estimators=150
# [CV 8/10; 11/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, n_estimators=150;, score=0.812 total time=  15.3s
# [CV 9/10; 11/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, n_estimators=150
# [CV 9/10; 11/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, n_estimators=150;, score=0.809 total time=  16.4s
# [CV 10/10; 11/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, n_estimators=150
# [CV 10/10; 11/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, n_estimators=150;, score=0.811 total time=  15.2s
# [CV 1/10; 12/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, n_estimators=200
# [CV 1/10; 12/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, n_estimators=200;, score=0.810 total time=  22.5s
# [CV 2/10; 12/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, n_estimators=200
# [CV 2/10; 12/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, n_estimators=200;, score=0.816 total time=  20.1s
# [CV 3/10; 12/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, n_estimators=200
# [CV 3/10; 12/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, n_estimators=200;, score=0.816 total time=  18.8s
# [CV 4/10; 12/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, n_estimators=200
# [CV 4/10; 12/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, n_estimators=200;, score=0.824 total time=  19.2s
# [CV 5/10; 12/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, n_estimators=200
# [CV 5/10; 12/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, n_estimators=200;, score=0.808 total time=  19.6s
# [CV 6/10; 12/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, n_estimators=200
# [CV 6/10; 12/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, n_estimators=200;, score=0.822 total time=  20.2s
# [CV 7/10; 12/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, n_estimators=200
# [CV 7/10; 12/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, n_estimators=200;, score=0.816 total time=  25.8s
# [CV 8/10; 12/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, n_estimators=200
# [CV 8/10; 12/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, n_estimators=200;, score=0.815 total time=  23.9s
# [CV 9/10; 12/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, n_estimators=200
# [CV 9/10; 12/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, n_estimators=200;, score=0.807 total time=  22.6s
# [CV 10/10; 12/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, n_estimators=200
# [CV 10/10; 12/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, n_estimators=200;, score=0.817 total time=  21.3s
# [CV 1/10; 13/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, n_estimators=100
# [CV 1/10; 13/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, n_estimators=100;, score=0.814 total time=  10.1s
# [CV 2/10; 13/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, n_estimators=100
# [CV 2/10; 13/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, n_estimators=100;, score=0.813 total time=  10.4s
# [CV 3/10; 13/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, n_estimators=100
# [CV 3/10; 13/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, n_estimators=100;, score=0.816 total time=  10.0s
# [CV 4/10; 13/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, n_estimators=100
# [CV 4/10; 13/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, n_estimators=100;, score=0.821 total time=  12.4s
# [CV 5/10; 13/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, n_estimators=100
# [CV 5/10; 13/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, n_estimators=100;, score=0.804 total time=  12.4s
# [CV 6/10; 13/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, n_estimators=100
# [CV 6/10; 13/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, n_estimators=100;, score=0.818 total time=  12.9s
# [CV 7/10; 13/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, n_estimators=100
# [CV 7/10; 13/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, n_estimators=100;, score=0.811 total time=  13.3s
# [CV 8/10; 13/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, n_estimators=100
# [CV 8/10; 13/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, n_estimators=100;, score=0.813 total time=  11.6s
# [CV 9/10; 13/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, n_estimators=100
# [CV 9/10; 13/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, n_estimators=100;, score=0.813 total time=  11.4s
# [CV 10/10; 13/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, n_estimators=100
# [CV 10/10; 13/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, n_estimators=100;, score=0.813 total time=  14.9s
# [CV 1/10; 14/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, n_estimators=150
# [CV 1/10; 14/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, n_estimators=150;, score=0.810 total time=  17.8s
# [CV 2/10; 14/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, n_estimators=150
# [CV 2/10; 14/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, n_estimators=150;, score=0.818 total time=  19.4s
# [CV 3/10; 14/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, n_estimators=150
# [CV 3/10; 14/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, n_estimators=150;, score=0.814 total time=  17.0s
# [CV 4/10; 14/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, n_estimators=150
# [CV 4/10; 14/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, n_estimators=150;, score=0.817 total time=  21.5s
# [CV 5/10; 14/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, n_estimators=150
# [CV 5/10; 14/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, n_estimators=150;, score=0.804 total time=  23.4s
# [CV 6/10; 14/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, n_estimators=150
# [CV 6/10; 14/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, n_estimators=150;, score=0.820 total time=  20.7s
# [CV 7/10; 14/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, n_estimators=150
# [CV 7/10; 14/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, n_estimators=150;, score=0.815 total time=  17.1s
# [CV 8/10; 14/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, n_estimators=150
# [CV 8/10; 14/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, n_estimators=150;, score=0.809 total time=  18.0s
# [CV 9/10; 14/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, n_estimators=150
# [CV 9/10; 14/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, n_estimators=150;, score=0.809 total time=  16.1s
# [CV 10/10; 14/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, n_estimators=150
# [CV 10/10; 14/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, n_estimators=150;, score=0.811 total time=  17.2s
# [CV 1/10; 15/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, n_estimators=200
# [CV 1/10; 15/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, n_estimators=200;, score=0.810 total time=  21.1s
# [CV 2/10; 15/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, n_estimators=200
# [CV 2/10; 15/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, n_estimators=200;, score=0.812 total time=  22.5s
# [CV 3/10; 15/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, n_estimators=200
# [CV 3/10; 15/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, n_estimators=200;, score=0.815 total time=  22.8s
# [CV 4/10; 15/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, n_estimators=200
# [CV 4/10; 15/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, n_estimators=200;, score=0.817 total time=  20.0s
# [CV 5/10; 15/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, n_estimators=200
# [CV 5/10; 15/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, n_estimators=200;, score=0.806 total time=  19.8s
# [CV 6/10; 15/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, n_estimators=200
# [CV 6/10; 15/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, n_estimators=200;, score=0.820 total time=  22.2s
# [CV 7/10; 15/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, n_estimators=200
# [CV 7/10; 15/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, n_estimators=200;, score=0.812 total time=  22.0s
# [CV 8/10; 15/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, n_estimators=200
# [CV 8/10; 15/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, n_estimators=200;, score=0.814 total time=  21.9s
# [CV 9/10; 15/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, n_estimators=200
# [CV 9/10; 15/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, n_estimators=200;, score=0.807 total time=  20.7s
# [CV 10/10; 15/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, n_estimators=200
# [CV 10/10; 15/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, n_estimators=200;, score=0.815 total time=  20.3s
# [CV 1/10; 16/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, n_estimators=100
# [CV 1/10; 16/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, n_estimators=100;, score=0.811 total time=  10.2s
# [CV 2/10; 16/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, n_estimators=100
# [CV 2/10; 16/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, n_estimators=100;, score=0.810 total time=  10.3s
# [CV 3/10; 16/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, n_estimators=100
# [CV 3/10; 16/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, n_estimators=100;, score=0.810 total time=  12.1s
# [CV 4/10; 16/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, n_estimators=100
# [CV 4/10; 16/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, n_estimators=100;, score=0.814 total time=  10.6s
# [CV 5/10; 16/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, n_estimators=100
# [CV 5/10; 16/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, n_estimators=100;, score=0.804 total time=  10.8s
# [CV 6/10; 16/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, n_estimators=100
# [CV 6/10; 16/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, n_estimators=100;, score=0.817 total time=  10.8s
# [CV 7/10; 16/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, n_estimators=100
# [CV 7/10; 16/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, n_estimators=100;, score=0.813 total time=  10.5s
# [CV 8/10; 16/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, n_estimators=100
# [CV 8/10; 16/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, n_estimators=100;, score=0.809 total time=  10.6s
# [CV 9/10; 16/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, n_estimators=100
# [CV 9/10; 16/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, n_estimators=100;, score=0.808 total time=  11.8s
# [CV 10/10; 16/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, n_estimators=100
# [CV 10/10; 16/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, n_estimators=100;, score=0.816 total time=  14.4s
# [CV 1/10; 17/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, n_estimators=150
# [CV 1/10; 17/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, n_estimators=150;, score=0.808 total time=  19.9s
# [CV 2/10; 17/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, n_estimators=150
# [CV 2/10; 17/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, n_estimators=150;, score=0.813 total time=  17.6s
# [CV 3/10; 17/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, n_estimators=150
# [CV 3/10; 17/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, n_estimators=150;, score=0.815 total time=  16.3s
# [CV 4/10; 17/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, n_estimators=150
# [CV 4/10; 17/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, n_estimators=150;, score=0.818 total time=  17.9s
# [CV 5/10; 17/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, n_estimators=150
# [CV 5/10; 17/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, n_estimators=150;, score=0.805 total time=  16.3s
# [CV 6/10; 17/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, n_estimators=150
# [CV 6/10; 17/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, n_estimators=150;, score=0.819 total time=  15.6s
# [CV 7/10; 17/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, n_estimators=150
# [CV 7/10; 17/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, n_estimators=150;, score=0.809 total time=  16.0s
# [CV 8/10; 17/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, n_estimators=150
# [CV 8/10; 17/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, n_estimators=150;, score=0.813 total time=  16.1s
# [CV 9/10; 17/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, n_estimators=150
# [CV 9/10; 17/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, n_estimators=150;, score=0.811 total time=  17.2s
# [CV 10/10; 17/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, n_estimators=150
# [CV 10/10; 17/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, n_estimators=150;, score=0.812 total time=  16.8s
# [CV 1/10; 18/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, n_estimators=200
# [CV 1/10; 18/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, n_estimators=200;, score=0.807 total time=  23.2s
# [CV 2/10; 18/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, n_estimators=200
# [CV 2/10; 18/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, n_estimators=200;, score=0.809 total time=  21.0s
# [CV 3/10; 18/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, n_estimators=200
# [CV 3/10; 18/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, n_estimators=200;, score=0.813 total time=  22.3s
# [CV 4/10; 18/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, n_estimators=200
# [CV 4/10; 18/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, n_estimators=200;, score=0.815 total time=  22.8s
# [CV 5/10; 18/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, n_estimators=200
# [CV 5/10; 18/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, n_estimators=200;, score=0.805 total time=  24.3s
# [CV 6/10; 18/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, n_estimators=200
# [CV 6/10; 18/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, n_estimators=200;, score=0.818 total time=  24.9s
# [CV 7/10; 18/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, n_estimators=200
# [CV 7/10; 18/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, n_estimators=200;, score=0.809 total time=  23.4s
# [CV 8/10; 18/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, n_estimators=200
# [CV 8/10; 18/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, n_estimators=200;, score=0.808 total time=  22.9s
# [CV 9/10; 18/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, n_estimators=200
# [CV 9/10; 18/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, n_estimators=200;, score=0.803 total time=  22.5s
# [CV 10/10; 18/108] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, n_estimators=200
# [CV 10/10; 18/108] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, n_estimators=200;, score=0.812 total time=  22.1s
# [CV 1/10; 19/108] START criterion=gini, max_depth=15, max_features=auto, min_samples_leaf=1, n_estimators=100
# [CV 1/10; 19/108] END criterion=gini, max_depth=15, max_features=auto, min_samples_leaf=1, n_estimators=100;, score=0.881 total time=  15.2s
# [CV 2/10; 19/108] START criterion=gini, max_depth=15, max_features=auto, min_samples_leaf=1, n_estimators=100
# [CV 2/10; 19/108] END criterion=gini, max_depth=15, max_features=auto, min_samples_leaf=1, n_estimators=100;, score=0.879 total time=  17.7s
# [CV 3/10; 19/108] START criterion=gini, max_depth=15, max_features=auto, min_samples_leaf=1, n_estimators=100
# [CV 3/10; 19/108] END criterion=gini, max_depth=15, max_features=auto, min_samples_leaf=1, n_estimators=100;, score=0.877 total time=  14.7s
# [CV 4/10; 19/108] START criterion=gini, max_depth=15, max_features=auto, min_samples_leaf=1, n_estimators=100
# [CV 4/10; 19/108] END criterion=gini, max_depth=15, max_features=auto, min_samples_leaf=1, n_estimators=100;, score=0.881 total time=  14.0s
# [CV 5/10; 19/108] START criterion=gini, max_depth=15, max_features=auto, min_samples_leaf=1, n_estimators=100
# [CV 5/10; 19/108] END criterion=gini, max_depth=15, max_features=auto, min_samples_leaf=1, n_estimators=100;, score=0.869 total time=  14.9s
# [CV 6/10; 19/108] START criterion=gini, max_depth=15, max_features=auto, min_samples_leaf=1, n_estimators=100
# [CV 6/10; 19/108] END criterion=gini, max_depth=15, max_features=auto, min_samples_leaf=1, n_estimators=100;, score=0.880 total time=  15.4s
# [CV 7/10; 19/108] START criterion=gini, max_depth=15, max_features=auto, min_samples_leaf=1, n_estimators=100
# [CV 7/10; 19/108] END criterion=gini, max_depth=15, max_features=auto, min_samples_leaf=1, n_estimators=100;, score=0.885 total time=  14.2s
# [CV 8/10; 19/108] START criterion=gini, max_depth=15, max_features=auto, min_samples_leaf=1, n_estimators=100
# [CV 8/10; 19/108] END criterion=gini, max_depth=15, max_features=auto, min_samples_leaf=1, n_estimators=100;, score=0.879 total time=  13.3s
# [CV 9/10; 19/108] START criterion=gini, max_depth=15, max_features=auto, min_samples_leaf=1, n_estimators=100
# [CV 9/10; 19/108] END criterion=gini, max_depth=15, max_features=auto, min_samples_leaf=1, n_estimators=100;, score=0.876 total time=  15.9s
# [CV 10/10; 19/108] START criterion=gini, max_depth=15, max_features=auto, min_samples_leaf=1, n_estimators=100
# [CV 10/10; 19/108] END criterion=gini, max_depth=15, max_features=auto, min_samples_leaf=1, n_estimators=100;, score=0.883 total time=  16.2s
# [CV 1/10; 20/108] START criterion=gini, max_depth=15, max_features=auto, min_samples_leaf=1, n_estimators=150
# ...
# [CV 10/10; 102/108] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, n_estimators=200
# [CV 10/10; 102/108] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, n_estimators=200;, score=0.899 total time= 1.4min
# [CV 1/10; 103/108] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, n_estimators=100
# [CV 1/10; 103/108] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, n_estimators=100;, score=0.898 total time=  42.4s
# [CV 2/10; 103/108] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, n_estimators=100
# [CV 2/10; 103/108] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, n_estimators=100;, score=0.899 total time=  41.9s
# [CV 3/10; 103/108] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, n_estimators=100
# [CV 3/10; 103/108] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, n_estimators=100;, score=0.897 total time=  42.2s
# [CV 4/10; 103/108] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, n_estimators=100
# [CV 4/10; 103/108] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, n_estimators=100;, score=0.898 total time=  42.9s
# [CV 5/10; 103/108] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, n_estimators=100
# [CV 5/10; 103/108] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, n_estimators=100;, score=0.888 total time=  44.2s
# [CV 6/10; 103/108] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, n_estimators=100
# [CV 6/10; 103/108] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, n_estimators=100;, score=0.897 total time=  43.4s
# [CV 7/10; 103/108] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, n_estimators=100
# [CV 7/10; 103/108] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, n_estimators=100;, score=0.900 total time=  40.9s
# [CV 8/10; 103/108] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, n_estimators=100
# [CV 8/10; 103/108] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, n_estimators=100;, score=0.897 total time=  41.7s
# [CV 9/10; 103/108] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, n_estimators=100
# [CV 9/10; 103/108] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, n_estimators=100;, score=0.892 total time=  41.1s
# [CV 10/10; 103/108] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, n_estimators=100
# [CV 10/10; 103/108] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, n_estimators=100;, score=0.896 total time=  41.7s
# [CV 1/10; 104/108] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, n_estimators=150
# [CV 1/10; 104/108] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, n_estimators=150;, score=0.898 total time= 1.1min
# [CV 2/10; 104/108] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, n_estimators=150
# [CV 2/10; 104/108] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, n_estimators=150;, score=0.899 total time= 1.2min
# [CV 3/10; 104/108] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, n_estimators=150
# [CV 3/10; 104/108] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, n_estimators=150;, score=0.897 total time= 1.1min
# [CV 4/10; 104/108] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, n_estimators=150
# [CV 4/10; 104/108] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, n_estimators=150;, score=0.899 total time= 1.1min
# [CV 5/10; 104/108] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, n_estimators=150
# [CV 5/10; 104/108] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, n_estimators=150;, score=0.889 total time= 1.1min
# [CV 6/10; 104/108] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, n_estimators=150
# [CV 6/10; 104/108] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, n_estimators=150;, score=0.898 total time= 1.1min
# [CV 7/10; 104/108] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, n_estimators=150
# [CV 7/10; 104/108] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, n_estimators=150;, score=0.902 total time= 1.1min
# [CV 8/10; 104/108] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, n_estimators=150
# [CV 8/10; 104/108] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, n_estimators=150;, score=0.898 total time=  59.4s
# [CV 9/10; 104/108] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, n_estimators=150
# [CV 9/10; 104/108] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, n_estimators=150;, score=0.894 total time= 1.0min
# [CV 10/10; 104/108] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, n_estimators=150
# [CV 10/10; 104/108] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, n_estimators=150;, score=0.893 total time=  60.0s
# [CV 1/10; 105/108] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, n_estimators=200
# [CV 1/10; 105/108] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, n_estimators=200;, score=0.899 total time= 1.3min
# [CV 2/10; 105/108] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, n_estimators=200
# [CV 2/10; 105/108] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, n_estimators=200;, score=0.896 total time= 1.3min
# [CV 3/10; 105/108] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, n_estimators=200
# [CV 3/10; 105/108] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, n_estimators=200;, score=0.897 total time= 1.3min
# [CV 4/10; 105/108] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, n_estimators=200
# [CV 4/10; 105/108] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, n_estimators=200;, score=0.902 total time= 1.3min
# [CV 5/10; 105/108] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, n_estimators=200
# [CV 5/10; 105/108] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, n_estimators=200;, score=0.888 total time= 1.3min
# [CV 6/10; 105/108] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, n_estimators=200
# [CV 6/10; 105/108] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, n_estimators=200;, score=0.897 total time= 1.3min
# [CV 7/10; 105/108] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, n_estimators=200
# [CV 7/10; 105/108] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, n_estimators=200;, score=0.902 total time= 1.3min
# [CV 8/10; 105/108] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, n_estimators=200
# [CV 8/10; 105/108] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, n_estimators=200;, score=0.895 total time= 1.4min
# [CV 9/10; 105/108] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, n_estimators=200
# [CV 9/10; 105/108] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, n_estimators=200;, score=0.891 total time= 1.5min
# [CV 10/10; 105/108] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, n_estimators=200
# [CV 10/10; 105/108] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, n_estimators=200;, score=0.896 total time= 1.5min
# [CV 1/10; 106/108] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=4, n_estimators=100
# [CV 1/10; 106/108] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=4, n_estimators=100;, score=0.888 total time=  43.3s
# [CV 2/10; 106/108] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=4, n_estimators=100
# [CV 2/10; 106/108] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=4, n_estimators=100;, score=0.890 total time=  44.7s
# [CV 3/10; 106/108] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=4, n_estimators=100
# [CV 3/10; 106/108] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=4, n_estimators=100;, score=0.890 total time=  41.6s
# [CV 4/10; 106/108] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=4, n_estimators=100
# [CV 4/10; 106/108] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=4, n_estimators=100;, score=0.892 total time=  36.3s
# [CV 5/10; 106/108] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=4, n_estimators=100
# [CV 5/10; 106/108] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=4, n_estimators=100;, score=0.882 total time=  35.9s
# [CV 6/10; 106/108] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=4, n_estimators=100
# [CV 6/10; 106/108] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=4, n_estimators=100;, score=0.891 total time=  35.6s
# [CV 7/10; 106/108] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=4, n_estimators=100
# [CV 7/10; 106/108] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=4, n_estimators=100;, score=0.891 total time=  37.5s
# [CV 8/10; 106/108] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=4, n_estimators=100
# [CV 8/10; 106/108] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=4, n_estimators=100;, score=0.892 total time=  35.0s
# [CV 9/10; 106/108] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=4, n_estimators=100
# [CV 9/10; 106/108] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=4, n_estimators=100;, score=0.882 total time=  35.4s
# [CV 10/10; 106/108] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=4, n_estimators=100
# [CV 10/10; 106/108] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=4, n_estimators=100;, score=0.887 total time=  35.8s
# [CV 1/10; 107/108] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=4, n_estimators=150
# [CV 1/10; 107/108] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=4, n_estimators=150;, score=0.889 total time=  53.0s
# [CV 2/10; 107/108] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=4, n_estimators=150
# [CV 2/10; 107/108] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=4, n_estimators=150;, score=0.889 total time=  53.1s
# [CV 3/10; 107/108] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=4, n_estimators=150
# [CV 3/10; 107/108] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=4, n_estimators=150;, score=0.891 total time= 1.3min
# [CV 4/10; 107/108] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=4, n_estimators=150
# [CV 4/10; 107/108] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=4, n_estimators=150;, score=0.893 total time= 1.1min
# [CV 5/10; 107/108] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=4, n_estimators=150
# [CV 5/10; 107/108] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=4, n_estimators=150;, score=0.881 total time=  59.0s
# [CV 6/10; 107/108] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=4, n_estimators=150
# [CV 6/10; 107/108] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=4, n_estimators=150;, score=0.889 total time=  57.2s
# [CV 7/10; 107/108] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=4, n_estimators=150
# [CV 7/10; 107/108] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=4, n_estimators=150;, score=0.894 total time= 1.1min
# [CV 8/10; 107/108] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=4, n_estimators=150
# [CV 8/10; 107/108] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=4, n_estimators=150;, score=0.891 total time= 1.1min
# [CV 9/10; 107/108] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=4, n_estimators=150
# [CV 9/10; 107/108] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=4, n_estimators=150;, score=0.881 total time= 1.0min
# [CV 10/10; 107/108] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=4, n_estimators=150
# [CV 10/10; 107/108] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=4, n_estimators=150;, score=0.888 total time= 1.1min
# [CV 1/10; 108/108] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=4, n_estimators=200
# [CV 1/10; 108/108] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=4, n_estimators=200;, score=0.890 total time= 1.3min
# [CV 2/10; 108/108] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=4, n_estimators=200
# [CV 2/10; 108/108] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=4, n_estimators=200;, score=0.891 total time= 1.2min
# [CV 3/10; 108/108] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=4, n_estimators=200
# [CV 3/10; 108/108] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=4, n_estimators=200;, score=0.889 total time= 1.2min
# [CV 4/10; 108/108] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=4, n_estimators=200
# [CV 4/10; 108/108] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=4, n_estimators=200;, score=0.893 total time= 1.2min
# [CV 5/10; 108/108] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=4, n_estimators=200
# [CV 5/10; 108/108] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=4, n_estimators=200;, score=0.882 total time= 1.2min
# [CV 6/10; 108/108] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=4, n_estimators=200
# [CV 6/10; 108/108] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=4, n_estimators=200;, score=0.892 total time= 1.3min
# [CV 7/10; 108/108] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=4, n_estimators=200
# [CV 7/10; 108/108] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=4, n_estimators=200;, score=0.893 total time= 1.4min
# [CV 8/10; 108/108] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=4, n_estimators=200
# [CV 8/10; 108/108] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=4, n_estimators=200;, score=0.889 total time= 1.4min
# [CV 9/10; 108/108] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=4, n_estimators=200
# [CV 9/10; 108/108] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=4, n_estimators=200;, score=0.884 total time= 1.5min
# [CV 10/10; 108/108] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=4, n_estimators=200
# [CV 10/10; 108/108] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=4, n_estimators=200;, score=0.889 total time= 1.4min
# Best score is: 0.9009884554794523
# Tuned Model Parameter: {'criterion': 'entropy', 'max_depth': 20, 'max_features': 'auto', 'min_samples_leaf': 1, 'n_estimators': 150}

# %%
model_rf_tuned = RandomForestClassifier(criterion='entropy',max_depth=20, max_features='auto', min_samples_leaf= 1, n_estimators=150)

# Fit the regressor to the training data
model_rf_tuned.fit(x_train_scaled, y_train.values.ravel())

# Prediction
train_pred_rf = model_rf_tuned.predict(x_train_scaled)
open_pred_rf = model_rf_tuned.predict(x_test_scaled)
hidden_pred_rf = model_rf_tuned.predict(x_hidden_scaled)
#Printing Reports 
#Printing Reports
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9348/3741857322.py in <module>
# ----> 1 model_rf_tuned = RandomForestClassifier(criterion='entropy',max_depth=20, max_features='auto', min_samples_leaf= 1, n_estimators=150)
#       2
#       3 # Fit the regressor to the training data
#       4 model_rf_tuned.fit(x_train_scaled, y_train.values.ravel())
#       5
#
# NameError: name 'RandomForestClassifier' is not defined

# %%
A = np.load('penalty_matrix.npy')
def score(y_true, y_pred):
    S = 0.0
    y_true = y_true.astype(int)
    y_pred = y_pred.astype(int)
    for i in range(0, y_true.shape[0]):
        S -= A[y_true[i], y_pred[i]]
    return S/y_true.shape[0]

# %%
from sklearn.metrics import classification_report, accuracy_score
print('-----------------------TRAIN SET REPORT---------------------')
print("Open set RMSE:", np.sqrt(mean_squared_error(y_train, train_pred_rf)))
print('Open set penalty matrix score:', score(y_train.values, train_pred_rf))
print('Open set report:', classification_report(y_train, train_pred_rf))
print('-----------------------OPEN SET REPORT---------------------')
print("Open set RMSE:", np.sqrt(mean_squared_error(y_test, open_pred_rf)))
print('Open set penalty matrix score:', score(y_test.values, open_pred_rf))
print('Open set report:', classification_report(y_test, open_pred_rf))
print('-----------------------HIDDEN SET REPORT---------------------')
print("Hidden set RMSE:", np.sqrt(mean_squared_error(y_hidden, hidden_pred_rf)))
print('Hidden set penalty matrix score:', score(y_hidden.values, hidden_pred_rf))
print('Hidden set report:', classification_report(y_hidden, hidden_pred_rf))
